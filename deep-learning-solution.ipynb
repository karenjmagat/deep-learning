# %% [markdown]
# ## Preprocessing

# %%
# !pip install --upgrade tensorflow==2.15
# Out:
# Requirement already satisfied: tensorflow==2.15 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (2.15.0)
# Requirement already satisfied: tensorflow-macos==2.15.0 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow==2.15) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (3.7.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (3.3.0)
# Requirement already satisfied: packaging in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (4.23.4)
# Requirement already satisfied: setuptools in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.15.0->tensorflow==2.15) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (2.26.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (2020.6.20)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/kmagat/anaconda3/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (3.2.2)

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow import keras


#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
application_df = application_df.drop(["EIN", "NAME"],1)
application_df.head()
# Out:
# /var/folders/ng/cy3hrs115yx93r5vsfvskf280000gn/T/ipykernel_54075/859502990.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   application_df = application_df.drop(["EIN", "NAME"],1)
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
#  YOUR CODE GOES HERE
application_counts = application_df["APPLICATION_TYPE"].value_counts()
application_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
application_types_to_replace = list(application_counts[application_counts < 500].index)
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
class_counts = application_df["CLASSIFICATION"].value_counts()
class_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
class_counts[class_counts >1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classifications_to_replace = list(class_counts[class_counts <1000].index)
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
application_with_dummies_df = pd.get_dummies(application_df)
application_with_dummies_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        0                    1                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    1                    0                    0  ...
# 34295                    1                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    0                    1                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
X = application_with_dummies_df.drop(["IS_SUCCESSFUL"], axis = "columns").values
y =application_with_dummies_df["IS_SUCCESSFUL"].values

# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
number_input_feature = len(X_train[0])
hidden_nodes_layers1 = 80
hidden_nodes_layers2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layers1,input_dim=number_input_feature, activation="relu")
)
# Second hidden layer
#  YOUR CODE GOES HERE
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layers2, activation="relu")
)
# Output layer
#  YOUR CODE GOES HERE
nn.add(
    tf.keras.layers.Dense(units=1, activation="sigmoid")
)
# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 80)                3520
#
#  dense_2 (Dense)             (None, 30)                2430
#
#  dense_3 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 5981 (23.36 KB)
# Trainable params: 5981 (23.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 494us/step - loss: 0.5722 - accuracy: 0.7213
# Epoch 2/100
# 804/804 [==============================] - 0s 484us/step - loss: 0.5568 - accuracy: 0.7301
# Epoch 3/100
# 804/804 [==============================] - 0s 491us/step - loss: 0.5532 - accuracy: 0.7320
# Epoch 4/100
# 804/804 [==============================] - 0s 487us/step - loss: 0.5518 - accuracy: 0.7316
# Epoch 5/100
# 804/804 [==============================] - 0s 482us/step - loss: 0.5511 - accuracy: 0.7332
# Epoch 6/100
# 804/804 [==============================] - 0s 491us/step - loss: 0.5494 - accuracy: 0.7341
# Epoch 7/100
# 804/804 [==============================] - 0s 498us/step - loss: 0.5488 - accuracy: 0.7341
# 804/804 [==============================] - 0s 522us/step - loss: 0.5375 - accuracy: 0.7404
# Epoch 72/100
# 804/804 [==============================] - 0s 513us/step - loss: 0.5374 - accuracy: 0.7402
# Epoch 73/100
# 804/804 [==============================] - 0s 502us/step - loss: 0.5379 - accuracy: 0.7395
# Epoch 74/100
# 804/804 [==============================] - 0s 499us/step - loss: 0.5374 - accuracy: 0.7406
# Epoch 75/100
# 804/804 [==============================] - 0s 498us/step - loss: 0.5377 - accuracy: 0.7402
# Epoch 76/100
# 804/804 [==============================] - 0s 500us/step - loss: 0.5374 - accuracy: 0.7395
# Epoch 77/100
# 804/804 [==============================] - 0s 520us/step - loss: 0.5373 - accuracy: 0.7400
# Epoch 78/100
# 804/804 [==============================] - 0s 507us/step - loss: 0.5369 - accuracy: 0.7402
# Epoch 79/100
# 804/804 [==============================] - 0s 504us/step - loss: 0.5372 - accuracy: 0.7399
# Epoch 80/100
# 804/804 [==============================] - 0s 519us/step - loss: 0.5370 - accuracy: 0.7399
# Epoch 81/100
# 804/804 [==============================] - 0s 510us/step - loss: 0.5374 - accuracy: 0.7400
# Epoch 82/100
# 804/804 [==============================] - 0s 499us/step - loss: 0.5366 - accuracy: 0.7394
# Epoch 83/100
# 804/804 [==============================] - 0s 496us/step - loss: 0.5368 - accuracy: 0.7410
# Epoch 84/100
# 804/804 [==============================] - 0s 494us/step - loss: 0.5371 - accuracy: 0.7403
# Epoch 85/100
# 804/804 [==============================] - 0s 493us/step - loss: 0.5370 - accuracy: 0.7405
# Epoch 86/100
# 804/804 [==============================] - 0s 495us/step - loss: 0.5365 - accuracy: 0.7400
# Epoch 87/100
# 804/804 [==============================] - 0s 499us/step - loss: 0.5365 - accuracy: 0.7395
# Epoch 88/100
# 804/804 [==============================] - 0s 498us/step - loss: 0.5369 - accuracy: 0.7404
# Epoch 89/100
# 804/804 [==============================] - 0s 497us/step - loss: 0.5363 - accuracy: 0.7405
# Epoch 90/100
# 804/804 [==============================] - 0s 497us/step - loss: 0.5365 - accuracy: 0.7404
# Epoch 91/100
# 804/804 [==============================] - 0s 497us/step - loss: 0.5365 - accuracy: 0.7402
# Epoch 92/100
# 804/804 [==============================] - 0s 504us/step - loss: 0.5362 - accuracy: 0.7404
# Epoch 93/100
# 804/804 [==============================] - 0s 502us/step - loss: 0.5363 - accuracy: 0.7400
# Epoch 94/100
# 804/804 [==============================] - 0s 503us/step - loss: 0.5363 - accuracy: 0.7403
# Epoch 95/100
# 804/804 [==============================] - 0s 506us/step - loss: 0.5359 - accuracy: 0.7406
# Epoch 96/100
# 804/804 [==============================] - 0s 502us/step - loss: 0.5363 - accuracy: 0.7407
# Epoch 97/100
# 804/804 [==============================] - 0s 508us/step - loss: 0.5359 - accuracy: 0.7409
# Epoch 98/100
# 804/804 [==============================] - 0s 519us/step - loss: 0.5364 - accuracy: 0.7409
# Epoch 99/100
# 804/804 [==============================] - 0s 498us/step - loss: 0.5362 - accuracy: 0.7408
# Epoch 100/100
# 804/804 [==============================] - 0s 490us/step - loss: 0.5359 - accuracy: 0.7413

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5555 - accuracy: 0.7268 - 147ms/epoch - 549us/step
# Loss: 0.5554801225662231, Accuracy: 0.7267638444900513

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn.save("AlphabetSoupCharity.h5")
# Out:
# /Users/kmagat/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
